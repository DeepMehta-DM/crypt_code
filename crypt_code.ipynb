# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
text_for_decryption = '''
        {1[&  {1[&  81..& +5=+[-  ,6  =85  41&  2+,=85+

=,41&  8  "1[=4  =,  =5]]  >  =81=  9  81<5  7+,"[  1[4  133,{.]9-854  -,  {>38  1[4  "5  1]]  1+5  <5+&  81..&  1[4  .+,>4  6,+  =81=

=,41&  ,[  =89-  -.5391]  41&  9  "1[=54  &,>  =,  }[,"  =81=  &,>  81<5  {1[1754  =89[7-  -,  "5]]  -,  61+  1[4  9  1{  .+,>4  ,6  &,>

{1&  7,4  2]5--  &,>  "9=8  1  851]=8&  1[4  1  2+978=  &51+  18514

],1=-  ,6  ],>5

0>-=  6,+  6>[  9  1{  1==1389[7  =",  .93-  "8938  -8,"-  &,>+  =+1[-6,+{1=9,[

 

                                                                                                                                09{9=
        '''

# %%
text_for_encryption = '''
        so finally jimit jiju here i am with a deep hearted (pun intended) reply
        
        today there are going to be things that i would share that i havent shared before
        firstly it was immense pleasure and fun decrypting your coded version of message 
        which of course as you said took me one hour to decrypt
        but yes it was all worth it
        
        moreover more than decrypting your code it took me time and efforts encrypting this back again
        i just wanted to feel what you would have felt while encoding it
        please decode it perfectly as i have proofread many times just to avoid mistakes
        so here i go
        
        i have always looked upto you as an elderly advice and have always consulted you in big decisions
        because i am sure that even if you may not have expertise in that direction
        u are survivor
        u n khanjan both are
        me taking this big step of coming here is just a reflection of you and khanjan setting an example for me
        so if you appreciate me for managing and growing here
        then part of it i owe it to you
        perhaps one of the most important one

        well i also remember my growth transformation which in a part also happened on the day
        jyaare amne police station wadi room chodwani hati n i was reluctant to even look at rooms in mira road
        regardless of knowing the monetary congestions and other factors of my family
        which again you were very much aware about
        and this day when you me and khushi were waiting at the corner paper wada ni dukan near manav kalyan signal
        and you for the first time in a little serious tone talked to me that i should get matured and try to not
        worsen the situation for my father right now
        and if i continue doing so then this is the last time u are explaining me anything and henceforth u wont
        sorry to interrupt but there is a secret word that you will need after reading whole text 
        to prove that you decoded it and the secret word is secret
        haha just for fun you will know once you complete now continue

        well to continue i am happy that i listen to u that day and i dont regeret any decisions taken
        of course there are many other things that you have done for me and my family in the course of time
        and i couldnt thank enough for any of that
        but lets keep it for another day
        as i know you would be bored decoding this or perhaps wouldnt have even reached until here
        hahah

        but ya as i mentioned earlier that one of the best thing you did today was to give me this challenging task
        which even i took as challenge and solve it
        but once i managed to figure out then my synister mind just gave me an idea that lets not end it here
        the fun just started
        
        so i even i took immense pleasure to express my feelings as detailed as possible
        hehe
        but of course thats for real
        
        also this is my first ever secret coded message conversation which as a child i have always wished on building

        so once you decode the whole message you can ask me for a secret and you will be happy to know it
        so reply me back the secret word
        bye

        deep
        
                      '''

# %%
def crypt_text(text):
    encrypt_text = {
        "a": "1", "n": "[",
        "b": "2", "o": ",",
        "c": "3", "p": ".", 
        "d": "4", "q": "*",
        "e": "5", "r": "+", 
        "f": "6", "s": "-",
        "g": "7", "t": "=",
        "h": "8", "u": ">",
        "i": "9", "v": "<",
        "j": "0", "w": "\"",
        "k": "}", "x": "/",
        "l": "]", "y": "&",
        "m": "{", "z": "%",    
    }
    decrypt_text = {v: k for k, v in encrypt_text.items()}
    encrypted_text = "".join([encrypt_text.get(c, c) for c in text])
    decrypted_text = "".join([decrypt_text.get(c, c) for c in text])
    print (decrypted_text)
    #print (encrypted_text)
    return

# %%
print(text_for_decryption)
crypt_text(text_for_decryption)
# Out:
#         {1[&  {1[&  81..& +5=+[-  ,6  =85  41&  2+,=85+
#
# =,41&  8  "1[=4  =,  =5]]  >  =81=  9  81<5  7+,"[  1[4  133,{.]9-854  -,  {>38  1[4  "5  1]]  1+5  <5+&  81..&  1[4  .+,>4  6,+  =81=
#
# =,41&  ,[  =89-  -.5391]  41&  9  "1[=54  &,>  =,  }[,"  =81=  &,>  81<5  {1[1754  =89[7-  -,  "5]]  -,  61+  1[4  9  1{  .+,>4  ,6  &,>
#
# {1&  7,4  2]5--  &,>  "9=8  1  851]=8&  1[4  1  2+978=  &51+  18514
#
# ],1=-  ,6  ],>5
#
# 0>-=  6,+  6>[  9  1{  1==1389[7  =",  .93-  "8938  -8,"-  &,>+  =+1[-6,+{1=9,[
#
#
#
#                                                                                                                                 09{9=
#
#
#         many  many  happy retrns  of  the  day  brother
#
# today  h  wantd  to  tell  u  that  i  have  grown  and  accomplished  so  much  and  we  all  are  very  happy  and  proud  for  that
#
# today  on  this  special  day  i  wanted  you  to  know  that  you  have  managed  things  so  well  so  far  and  i  am  proud  of  you
#
# ...

# %%
crypt_text(text_for_encryption)
# Out:
#         so finally jimit jiju here i am with a deep hearted (pun intended) reply
#
#         today there are going to be things that i would share that i havent shared before
#         firstly it was immense pleasure and fun decrypting your coded version of message
#         which of course as you said took me one hour to decrypt
#         but yes it was all worth it
#
#         moreover more than decrypting your code it took me time and efforts encrypting this back again
#         i just wanted to feel what you would have felt while encoding it
#         please decode it perfectly as i have proofread many times just to avoid mistakes
#         so here i go
#
#         i have always looked upto you as an elderly advice and have always consulted you in big decisions
#         because i am sure that even if you may not have expertise in that direction
#         u are survivor
#         u n khanjan both are
# ...
